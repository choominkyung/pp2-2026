# %% [markdown]
# # chapter 02 변수와 수식

# %% [markdown]
# - 변수란?
# : 컴퓨터의 메모리 공간에 이름을 붙이는 것
# : 이름과 값을 가지고 있음
#
# - =
# 양변이 같다(==)라는 뜻이 아닌, 변수에 값에 저장하라 라는 의미임
#
#
# - 변수의 이름
# : 첫 글자 영문자, 밑줄로 시작
# : #사용불가
# : 공백허용불가
# : 예약어 사용금지

# %% [markdown]
# - 변수의 세부 구현 사항
#   * 변수의 참조값을 알고 싶다면 id()함수 사용하기

# %%
x=3
id(x)
# Out:
# 140711496246456

# %% [markdown]
# - 불변객체와 가변객체
#   * 불변객체: 정수, 부동소수점, 문자열
#   * 가변객체: 리스트, 딕셔너리

# %% [markdown]
# ### lab _ 별까지의 거리 계산 프로그램

# %%
## 이 프로그램은 빛이 가는 시간을 계산한다.
speed = 300000.0
distance = 40000000000000.0
secs = distance / speed
light_year = secs / (60.0 * 60.0 * 24.0 * 365.0)
print(light_year, "광년")
# Out:
# 4.227972264501945 광년

# %% [markdown]
# - 주석과 상수
#   * 주석: 소스 코드에 붙이는 설명글 같은 것
#   * #을 이용해 줄의 끝까지 주석으로 취급함
#
#   *상수 : 한번 값이 결정되면 절대로 변경되지 않는 변수

# %% [markdown]
# ### lab _ 원기둥의 부피 계산하기

# %%
# 원기둥의 부피를 계산한다.

#원주율을 나타내는 상수를 정의한다.
PI = 3.14

#변수를 정의한다.
radius =5
height =10

#부피 계산
volume = PI * radius * radius * height

#결과 출력
print("반지름=", radius, "높이", height ,"원기둥의 면적=", volume)
# Out:
# 반지름= 5 높이 10 원기둥의 면적= 785.0

# %% [markdown]
# - 수식
#   * 산술 연산 : +-*/
#   * 할당 연산 = 대입연산자
#   : =을 활용함
#   * 복합 연산자: +-
#   * 지수 계산하기
#   :ex) 2**17

# %% [markdown]
# ### lab_ 복리 계산 프로그램

# %%
init_money =24
interest =0.08
years=382
print(init_money*(1+interest)** years)
# Out:
# 140632545501736.62

# %% [markdown]
# - 타입 변환과 반올림
# : 정수와 부동소수점수를 동시에 사용하여 수식을 만들면 자동적으로 부동소수점수로 변환함

# %%
3**1.23
# Out:
# 3.8624168522314024

# %% [markdown]
# - 문자열이란?
# : 문자들의 나열
#
# - 문자열을 만드는 방법
# : 큰 따옴표 사용하기
# : 작은 따옴표 사용하기
# *큰따옴표로 시작하여 작은 따옴표로는 불가*
#
# - 문자열의 결합과 반복
# +라는 연산자로 문자열결합가능
# *로 길이반복 가능

# %% [markdown]
# ### 로봇 기자 만들기 프로그램

# %%
#사용자의 대답을 변수에 저장한다.
stadium = input("경기장이 어디입니까?")
winner = input("이긴팀은 어디입니까?")
loser = input("진팀은 어디입니까")
vip = input("우수선수는 누구입니까")
score= input("스코어는 몇대 몇입니까")

#변수와 문자열을 연결하여 기사를 작성한다.
print("")
print("================================")
print("오늘", stadium, "에서 야구 경기가 열렸습니다.")
print(winner, "과", loser, "은 치열한 공방전을 펼쳤습니다.")
print(vip, "이 맹활약을 하였습니다.")
print("결국", winner, "가", loser, "를 ", score, "로 이겼습니다.")
print("=====================================")
# Out:
# ================================
# 오늘 t서울 에서 야구 경기가 열렸습니다.
# 삼성 과 LG 은 치열한 공방전을 펼쳤습니다.
# 홍길동 이 맹활약을 하였습니다.
# 결국 삼성 가 LG 를  8:7 로 이겼습니다.
# =====================================

# %% [markdown]
# - 입력과 출력
# : input()함수 사용하기

# %%
x = input("이름을 입력하시오:")
print(x)
# Out:
# 홍길동

# %% [markdown]
# ### lab_ 친근하게 대화하는 프로그램

# %%
##
# 이 프로그램은 사용자와 친근하게 대화한다.
#
print("안녕하세요?")
name = input("이름이 어떻게 되시나요? ")
print("만나서 반갑습니다. " + name + "씨")

print("이름의 길이는 다음과 같군요:", len(name))

age = int(input("나이가 어떻게 되나요? "))
print("내년이면 "+ str(age+1) + "이 되시는군요.")
# Out:
# 안녕하세요?
# 만나서 반갑습니다. 홍길동씨
# 이름의 길이는 다음과 같군요: 3
# 내년이면 22이 되시는군요.

# %% [markdown]
# ### lab_ 사각형그리기

# %%
##
# 이 프로그램은 사각형을 그린다.
#
import turtle
t = turtle.Turtle()
t.shape("turtle")

# 사용자로부터 사각형의 크기를 받아서 size라는 변수에 저장한다.
# 사각형의 크기는 정수이므로 input()이 반환하는 문자열을 int()를 통하여 정수로
# 변환하였다.
size = int(input("사각형의 크기는 얼마로 할까요? "))

# 사각형을 다음과 같은 코드로 그린 다. 이때 변수 size를 사용하자.
t.forward(size)        # size 만큼 거북이를 전진시킨다.
t.right(90)            # 거북이를 오른쪽으로 90도 회전시킨다.
t.forward(size)
t.right(90)
t.forward(size)
t.right(90)
t.forward(size)

turtle.mainloop()
turtle.bye()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[11], line 23
#      19 t.right(90)
#      20 t.forward(size)
#      21
#      22 turtle.mainloop()
# ---> 23 turtle.bye()
#
# File <string>:5, in bye()
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# Terminator:

# %% [markdown]
# ### bmi 계산하기

# %%
##
# 이 프로그램은 BMI를 계산한다.
#
weight = float(input("몸무게를 kg 단위로 입력하시오: "))
height = float(input("키를 미터 단위로 입력하시오: "))

bmi = (weight / (height**2))
print("당신의 BMI=", bmi)
# Out:
# 당신의 BMI= 25.381468541909282

# %% [markdown]
# ### lab_ 구의 부피 계산하기

# %%
##
# 이 프로그램은 구의 부피를 계산한다.
#

# 사용자에게 구의 반지름을 입력하도록 한다. 구의 반지름을 문자열에서 실수로
# 변환한다.
r = float(input("반지름을 입력하시오: "))

# 구의 부피를 공식을 이용하여 계산한다.
volume = (4.0/3.0) * 3.141592 * r**3

# 구의 부피를 화면에 출력한다.
print("구의 부피=", volume)
# Out:
# 구의 부피= 523.5986666666666

# %% [markdown]
# ### lab_ 자동판매기프로그램

# %%
##
# 이 프로그램은 자판기에서 거스름돈을 계산한다.
#
itemPrice = int(input("물건값을 입력하시오: "))
print("===입력금액===")
note = int(input("1000원 지폐개수: "))
coin500 = int(input("500원 동전개수: "))
coin100 = int(input("100원 동전개수: "))

change = note*1000 + coin500*500 + coin100*100 - itemPrice

# 거스름돈(500원 동전 개수)을 계산한다.
nCoin500 = change//500
change = change%500

# 거스름돈(100원 동전 개수)을 계산한다.
nCoin100 = change//100
change = change%100

# 거스름돈(10원 동전 개수)을 계산한다.
nCoin10 = change//10
change = change%10

# 거스름돈(1원 동전 개수)을 계산한다.
nCoin1 = change

print("===거스름돈 출력===")
print("500원=", nCoin500, "100원=", nCoin100, "10원=", nCoin10, "1원=", nCoin1)
# Out:
# ===입력금액===
# ===거스름돈 출력===
# 500원= 0 100원= 2 10원= 5 1원= 0
