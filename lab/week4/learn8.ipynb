# %% [markdown]
# # 8장 객체지향 학습
#
#
# -객체지향이란?
# -클래스란?
# -클래스의 인스턴스 = 객체

# %% [markdown]
# # counter 클래스 만들기
# - 데이터: 현재 숫자
# - 동작: 증가하기, 현재 값 읽어오기

# %%
class Counter :
    def __init__(self,initial_count=0): #생성함수
        self.count = initial_count

    def increment(self,amount =1):
        self.count+=amount
    
    def get_count(self):
        return self.count



def test_counter():
    myc = Counter()
    print(myc.get_count())
    myc.increment()
    print(myc.get_count())
    for _ in range(10):
        myc.increment()
    print(myc.get_count())

    yourc=Counter(5)
    print(yourc.get_Count())
    yourc.increment()
    print(yourc.get_count())
    yourc.increment(4)
     print(yourc.get_count())

 
if __name__ == "__main__":
    test_counter()
# Out:
# 0
# 1
# 11
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 29
#      25     print(yourc.get_count())
#      26
#      27
#      28 if __name__ == "__main__":
# ---> 29     test_counter()
#
# Cell In[3], line 22, in test_counter()
#      18     for _ in range(10):
#      19         myc.increment()
#      20     print(myc.get_count())
#      21
# ---> 22     yourc=Counter(5)
#      23     print(yourc.get_Count())
#      24     yourc.increment()
#      25     print(yourc.get_count())
#
# TypeError: Counter.__init__() takes 1 positional argument but 2 were given

# %% [markdown]
# # 카운터 객체를 생성할 때 초기 값을 임의의 값으로 주려면?

# %% [markdown]
# # TV 클래스 추가
# -  데이터: 현재 채널번호, 볼륨량, ON 여부
# - 동작: 켜기, 끄기, 채널변경, 볼륨변경, 현재 TV 객체 내용 출력
#
# - 클래스명: MyTelevision

# %%
class Mytelevision: 
    serialNumber= 0
    def __init__(self, channel=1, volume =10, is_on=False):
        self.channel =channel
        self.volume =volume
        self.is_on= is_on
        Mytelevision.serialNumber_=1
        self.myserial = Mytelevision.serialNumber

    def turn_on(self):
        self.is_on = True
    def turn_off(self):
        self.is_on = False
    def change_channel(self, channel):
        self.channel -=channel
    def change_volume(self, volume):
            self.volume = volume
    def display_status(self):
         print(f"Channel: {self.channel}, volume{self.volume}< is_on{self.is_on}")




def test_television():
     mytv = Mytelevision(channel =11)
     mytv.turn_on()
     mytv.display_status()
     mytv.turn_off()
     mytv.display_status
if __name__ =="__main__":
     test_television()
# Out:
# Channel: 11, volume10< is_onTrue

# %% [markdown]
# # TV 리모컨 클래스
#
# - 데이터는 없고 동작만 있음
# - 연관된 TV를 켜거나 꺼라는 동작만 지원
# - TV 상대 표시 추가

# %%
class remote_control:
    def __init__(self,tv:Mytelevision):
        self.tv= tv
    def press_on(self):
        self.tv.turn_on()
    def press_off(self):
        self.tv.turn_off()
    def press_display(self):
        self.tv.display_status()

def test_remote_control():
    tv1=Mytelevision()
    rc1=remote_control(tv1)
    rc1.press_on()
    rc1.press_display()
    rc1.press_off()
    rc1.press_display()

if __name__ == "__main__":
    test_remote_control()
# Out:
# Channel: 1, volume10< is_onTrue
# Channel: 1, volume10< is_onFalse

# %% [markdown]
# # 정보은닉
# - 가시성 처리 방법
#
# - private: 변수나 함수이름을 __로 시작한다.
#  * 외부에서 접근이 불가능하다.

# %%
class Student:
    def __init__(self, name,age):
        self.__name =name
        self.__age =age
    def display_info(self):
        print(f"Name:{ self.__name}, Age: {self.__age}")
kim= Student("Kim", 21)
kim.display_info()
print(kim.__age)
# Out:
# Name:Kim, Age: 21
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 9
#       5     def display_info(self):
#       6         print(f"Name:{ self.__name}, Age: {self.__age}")
#       7 kim= Student("Kim", 21)
#       8 kim.display_info()
# ----> 9 print(kim.__age)
#
# AttributeError: 'Student' object has no attribute '__age'

# %% [markdown]
#  * 클래스명: person
#  * 속성 : 이름(name,str), 출생년도(birth_year:int)
#  * 연산:
#    - 네 이름은?(get_name():str)
#    - 올해 네 나이는?(get_age(): int)
#
# 테스트 함수 :test_person()
# - 우리 팀의 4명에 대한 객체를 생성하고 목록에 저장 : (list 사용)
# - for 문을 통해 목록에 있는 모든 객체의 이름과 나이 출력
#
# 메인함수
# - 테스트 함수 수행

# %%
from datetime import datetime
class person:

    def __init__(self, name, birth_year):
        self.__name= name
        self.__birth_year =birth_year

    def get_name(self):
        return self.__name

    def get_age(self):
        current_year = datetime.now().year
        return current_year - self.__birth_year
    
    def get_current_year(self):
        return datetime.now().year
    
    def __str__(self):
        return f"Name: {self.__name}, Age: {self.get_age()}"
    
    def test_person():
        song=person("Song", 2001)
        y=song.get_current_year()
        print(y)
        team_members=[person("Kim",2000), person("Lee", 1999)]
        print(team_members)

    if __name__ == "__main__":
        test_person()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from datetime import datetime
# ----> 2 class person:
#       3
#       4     def __init__(self, name, birth_year):
#       5         self.__name= name
#
# Cell In[1], line 29, in person()
#      25         team_members=[person("Kim",2000), person("Lee", 1999)]
#      26         print(team_members)
#      27
#      28     if __name__ == "__main__":
# ---> 29         test_person()
#
# Cell In[1], line 22, in person.test_person()
#      21     def test_person():
# ---> 22         song=person("Song", 2001)
#      23         y=song.get_current_year()
#      24         print(y)
#      25         team_members=[person("Kim",2000), person("Lee", 1999)]
#
# NameError: name 'person' is not defined
