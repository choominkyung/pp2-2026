# %% [markdown]
# # chapter07 튜플, 딕셔너리, 문자열

# %% [markdown]
# 자료구조란?
# : 파이썬에서 자료들을 저장하는 여러가지 구조라고 말한다.

# %% [markdown]
# - 튜플
# : 인덱싱, 슬라이싱 지원가능
# : **변경불가**
# : ()로 표현함
# : **(,) 로 추가하여함**
#
# : enumerate()  : 요소의 인덱스값이 필요한 경우에 사용가능

# %% [markdown]
# - 세트
# : 고유한 값을 저장하는 자료구조
# : 특정 순서 없음
# : 우치ㅣ별로 액세스불가
# : 중복항목불가
# : {}로 표현
# : all(), any(), enumerate(), len(), max(), min(), sorted(), sum()
# : add()로 추가가능
# : remove()로 삭제가능
# :clear()로 전부삭제가능

# %% [markdown]
# ### lab_ 문자열의 공통문자

# %%
s1=input("첫 번째 문자열:")
s2=input("두 번째 문자열:")

list1 = list( set(s1) & set(s2) )          # 세트로 만들고 교집합 연산을 한다.

print("\n공통적인 글자:", end=" ")
for i in list1:
    print(i, end=" ")
# Out:
# 공통적인 글자: H r o e

# %% [markdown]
# ### lab_ 중복되지 않은 단어의 개수 세기

# %%
txt = input("입력 텍스트: ")
words = txt.split(" ")
unique = set(words)    # 집합으로 만들면 자동적으로 중복을 제거한다.

print("사용된 단어의 개수= ", len(unique))
print(unique)
# Out:
# 사용된 단어의 개수=  19
# {'', 'everry', 'day', 'main', 'every', 'i', 'exalted', 'have', 'valley', 'that', 'a', 'shall', 'be', 'mountian', 'one', 'hill', 'dream', 'low', 'and'}

# %% [markdown]
# -  딕셔너리
# : 값과 키도 저장됨
# : 중괄호로 구분
# : 값과 키 사이의 ;이 있어야함

# %% [markdown]
# ### lab_영한 사전

# %%
english_dict ={}            # 공백 딕셔너리를 생성한다.

english_dict["one"]="하나"   # 딕셔너리에 단어와 의미를 추가한다.
english_dict["two"]="둘"
english_dict["three"]="셋"

word = input("단어를 입력하시오: ");
print (english_dict[word])
# Out:
# 하나

# %% [markdown]
# ### lab_ 주소록 작성

# %%
def main():
    address_book ={}                                # 공백 딕셔너리를 생성한다.
    while True :
        user = display_menu();
        if user ==1 :
            name, number = get_contact()
            address_book[name]= number            # name과 number를 추가한다.
        elif user ==2 :
            name, number = get_contact()
            address_book.pop(name)               # name을 키로 가지고 항목을 삭제한다.
        elif user ==3 :
            pass                                 # 도전 문제 참조
        elif user ==4 :
            for key in sorted(address_book):
                print(key,"의 전화번호:", address_book[key])
        else :
            break

# 이름과 전화번호를 입력받아서 반환한다.
def get_contact():
    name =input("이름: ")
    number =input("전화번호:")
    return name, number                          # 튜플로 반환한다.

# 메뉴를 화면에 출력한다.
def display_menu() :
    print("1. 연락처 추가")
    print("2. 연락처 삭제")
    print("3. 연락처 검색")
    print("4. 연락처 출력")
    print("5. 종료")
    select = int(input("메뉴 항목을 선택하시오: "))
    return select

main()
# Out:
# 1. 연락처 추가
# 2. 연락처 삭제
# 3. 연락처 검색
# 4. 연락처 출력
# 5. 종료
# 1. 연락처 추가
# 2. 연락처 삭제
# 3. 연락처 검색
# 4. 연락처 출력
# 5. 종료
# KIM 의 전화번호: 123-4567
# 1. 연락처 추가
# 2. 연락처 삭제
# 3. 연락처 검색
# 4. 연락처 출력
# 5. 종료
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 35
#      31     print("5. 종료")
#      32     select = int(input("메뉴 항목을 선택하시오: "))
#      33     return select
#      34
# ---> 35 main()
#
# Cell In[4], line 4, in main()
#       1 def main():
#       2     address_book ={}                                # 공백 딕셔너리를 생성한다.
#       3     while True :
# ----> 4         user = display_menu();
#       5         if user ==1 :
#       6             name, number = get_contact()
#       7             address_book[name]= number            # name과 number를 추가한다.
#
# Cell In[4], line 32, in display_menu()
#      28     print("2. 연락처 삭제")
#      29     print("3. 연락처 검색")
#      30     print("4. 연락처 출력")
#      31     print("5. 종료")
# ---> 32     select = int(input("메뉴 항목을 선택하시오: "))
#      33     return select
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### lab_ 학생성적처리

# %%
score_dic = {
    "Kim":[99,83,95],
    "Lee":[68,45,78],
    "Choi":[25,56,69]
}

for name, scores in score_dic.items():
    print(name,"의 평균성적=",sum(scores)/len(scores))
# Out:
# Kim 의 평균성적= 92.33333333333333
# Lee 의 평균성적= 63.666666666666664
# Choi 의 평균성적= 50.0

# %% [markdown]
# ### lab_ 단어카운터만들기

# %%
text_data ="Create the highest, grandest vision possible for your life, because you become what you believe"

word_dic = {}                    # 단어들과 출현 횟수를 저장하는 딕셔너리를 생성
for w in text_data.split():     # 텍스트를 단어들로 분리하여 반복한다.
    if w in word_dic:           # 단어가 이미 딕셔너리에 있으면
        word_dic[w] += 1        # 출현 횟수를 1 증가한다.
    else:                       # 처음 나온 단어이면 1로 초기화한다.
        word_dic[w] = 1

for w, count in sorted(word_dic.items()): # 키와 값을 정렬하여 반복 처리한다.
    print(w, "의 등장횟수=", count)
# Out:
# Create 의 등장횟수= 1
# because 의 등장횟수= 1
# become 의 등장횟수= 1
# believe 의 등장횟수= 1
# for 의 등장횟수= 1
# grandest 의 등장횟수= 1
# highest, 의 등장횟수= 1
# life, 의 등장횟수= 1
# possible 의 등장횟수= 1
# the 의 등장횟수= 1
# vision 의 등장횟수= 1
# what 의 등장횟수= 1
# you 의 등장횟수= 2
# your 의 등장횟수= 1

# %% [markdown]
# - 문자열
#   * chr() : 정수를 문자로 변환
#   * ord() : 문자를 정수로 변환
#   * len() : 문자열의 길이 변환
#   * str() : 객체의 문자열 표현을 반환

# %% [markdown]
# ### lab_ 회문 검사하기

# %%
s = input("문자열을 입력하시오: ")

s1 = s[::-1]             # 문자열을 거꾸로 만든다.

if(s == s1):
    print("회문입니다.")
else:
    print("회문이 아닙니다.")
# Out:
# 회문입니다.

# %% [markdown]
# - 대소문자 변환하기 : s.capitalize
# - 찾기 및 바꾸기 :
#   * replace() :문자열에서 부분 문자열을 다른 부분 문자열로 변환
#   * find() : 부분 문자열 안에서 찾아서 인덱스 변환
#   * count() : 부분 문자열이 등장하는 횟수 반환
